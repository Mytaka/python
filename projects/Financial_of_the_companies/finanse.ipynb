# %%
import numpy as np
import pandas as pd

df = pd.read_csv('projects\Financial_of_the_companies\dataset.csv')
print(df.info())

print(df.head())

# df['2023'].dropna(how=any,inplace=True)
# print(df['2023'][:])

ser = df.groupby('Територіальний розріз')['2021'].sum()

print(df.groupby('Територіальний розріз')['2021','2022','2023'].sum())
# print(ser.plot())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 df = pd.read_csv('projects\Financial_of_the_companies\dataset.csv')
#       5 print(df.info())
#       7 print(df.head())
#
# ...

# %%
import matplotlib.pyplot as plt

# Данные
values = [1.338868e+12, 1.136998e+12, 1.052044e+12]
labels = ['Value 1', 'Value 2', 'Value 3']

# Построение графика
plt.plot(labels, values, marker='o', linestyle='-', color='b')

# Добавление подписей
plt.title('График значений')
plt.xlabel('Метки')
plt.ylabel('Значения')

# Отображение графика
plt.show()

# %%
print(1.338868*10**12 - 1.052044*10**12)
286_824_000_000
144_500_000_000
# Out:
# 286824000000.0
# 144500000000
